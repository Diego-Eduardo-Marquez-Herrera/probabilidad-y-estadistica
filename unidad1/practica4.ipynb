# %% [markdown]
# <a href="https://colab.research.google.com/github/Diego-Eduardo-Marquez-Herrera/probabilidad-y-estadistica/blob/main/unidad1/practica4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
fabrica1 = []
for i in range(100):
  numero_aleatorio = round(random. uniform(50,100) , 2 )
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [77.19, 70.2, 56.87, 66.61, 59.64, 78.4, 98.97, 79.42, 76.17, 62.96, 87.35, 84.26, 86.1, 97.77, 90.45, 55.24, 71.28, 86.41, 71.11, 76.33, 64.16, 84.12, 74.7, 92.48, 99.64, 87.1, 79.58, 52.3, 68.97, 71.01, 65.08, 85.64, 56.73, 90.17, 81.85, 52.95, 65.43, 97.72, 87.95, 98.19, 82.28, 86.77, 95.31, 88.93, 58.41, 60.59, 88.59, 92.7, 75.13, 82.3, 90.71, 99.69, 71.32, 96.05, 69.8, 79.12, 52.78, 62.18, 92.2, 67.28, 76.94, 58.7, 56.6, 55.63, 75.89, 62.23, 92.57, 74.15, 69.84, 76.96, 67.66, 76.06, 76.17, 97.35, 54.29, 51.93, 92.74, 87.14, 61.34, 55.98, 61.72, 99.05, 88.18, 80.45, 66.69, 85.5, 76.28, 73.19, 94.9, 74.77, 75.59, 62.91, 98.85, 74.69, 60.22, 88.19, 96.91, 80.84, 61.65, 51.16]

# %%
fabrica2 = []
for i in range(100):
  numero_aleatorio2 = round(random. uniform(70,100) , 2 )
  fabrica2.append(numero_aleatorio2)
print(fabrica2)
# Out:
# [93.57, 98.3, 71.07, 84.91, 90.75, 97.13, 99.0, 82.65, 91.52, 89.65, 73.85, 70.58, 82.18, 87.83, 76.85, 81.61, 72.56, 91.61, 92.78, 85.63, 80.22, 94.71, 99.31, 98.94, 75.71, 75.91, 80.31, 83.44, 83.33, 74.82, 75.97, 86.67, 83.44, 71.7, 89.82, 97.55, 94.36, 86.25, 92.86, 96.58, 94.43, 96.74, 99.42, 92.77, 71.13, 73.68, 92.86, 95.42, 96.76, 71.67, 94.19, 94.98, 72.36, 83.69, 78.32, 98.76, 84.64, 83.55, 70.56, 93.51, 83.44, 75.9, 70.26, 71.26, 75.78, 80.83, 86.94, 90.1, 77.28, 87.14, 96.71, 95.7, 89.02, 83.75, 76.33, 95.43, 96.81, 84.99, 94.13, 89.61, 76.35, 81.4, 97.42, 89.84, 92.11, 95.3, 77.37, 85.56, 92.86, 91.04, 82.59, 86.37, 85.42, 75.73, 77.54, 91.92, 93.12, 95.63, 86.31, 76.89]

# %%
plt.boxplot(fabrica1)
plt.ylabel("edades")
plt.title("Produccion fabrica1")
plt.show()

# %%
fig, ( ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9,4))
bplot1 = ax1.boxplot(fabrica1,
                     vert=True, # vertical box aligment
                     patch_artist=True) # fill with color
ax1.set_title("produccion fabrica 1")

bplot2 = ax2.boxplot(fabrica2,
                     vert=True, # vertical box aligment
                     patch_artist=True) # fill with color
ax2.set_title("produccion fabrica 2")
plt.show()

# %%
fabrica1.append(150)
print(fabrica1)
# Out:
# [77.19, 70.2, 56.87, 66.61, 59.64, 78.4, 98.97, 79.42, 76.17, 62.96, 87.35, 84.26, 86.1, 97.77, 90.45, 55.24, 71.28, 86.41, 71.11, 76.33, 64.16, 84.12, 74.7, 92.48, 99.64, 87.1, 79.58, 52.3, 68.97, 71.01, 65.08, 85.64, 56.73, 90.17, 81.85, 52.95, 65.43, 97.72, 87.95, 98.19, 82.28, 86.77, 95.31, 88.93, 58.41, 60.59, 88.59, 92.7, 75.13, 82.3, 90.71, 99.69, 71.32, 96.05, 69.8, 79.12, 52.78, 62.18, 92.2, 67.28, 76.94, 58.7, 56.6, 55.63, 75.89, 62.23, 92.57, 74.15, 69.84, 76.96, 67.66, 76.06, 76.17, 97.35, 54.29, 51.93, 92.74, 87.14, 61.34, 55.98, 61.72, 99.05, 88.18, 80.45, 66.69, 85.5, 76.28, 73.19, 94.9, 74.77, 75.59, 62.91, 98.85, 74.69, 60.22, 88.19, 96.91, 80.84, 61.65, 51.16, 150]

# %%
fig, ( ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9,4))
bplot1 = ax1.boxplot(fabrica1,
                     vert=True, # vertical box aligment
                     patch_artist=True) # fill with color
ax1.set_title("produccion fabrica 1")

bplot2 = ax2.boxplot(fabrica2,
                     vert=True, # vertical box aligment
                     patch_artist=True) # fill with color
ax2.set_title("produccion fabrica 2")
plt.show()
